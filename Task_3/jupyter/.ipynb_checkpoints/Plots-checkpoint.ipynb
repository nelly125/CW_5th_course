# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd2
from matplotlib.projections import polar
from tqdm import tqdm
import matplotlib.ticker as ticker

# %%
gamma = 1.4

def Plot(r, theta, Phi):
    fig = plt.figure(figsize=(10, 10))
    R, Theta = np.meshgrid(r, theta)
    ax = fig.add_subplot(111)
    c = ax.pcolormesh(R, Theta, Phi.T, cmap='viridis')
    plt.colorbar(c, ax=ax, label='')
    plt.xlabel('r', fontsize=18)
    plt.ylabel("theta", fontsize=18)
    plt.title("Phi", fontsize=18)
    plt.show()
    
def get_cp(Phi, eta):
    h_eta = eta[1] - eta[0]
    print(h_eta)
    dPhi_deta = (Phi[1, :] - Phi[0, : ]) / (h_eta)
    print(dPhi_deta[250])
    cp = 1 - dPhi_deta**2
    return cp
    
def Plot_cp(cp, eta):    
    plt.plot(eta, cp)
    plt.xlabel('Eta')
    plt.ylabel('cp')
    plt.title('cp')
    plt.show()
    
def get_local_Mach(u, v, p, Mach):
    a2 = 1.4 * p[0, :] **(1.4 - 1)
    M2 = (u[0, :]**2 + v[0, :]**2) / a2
    M = np.sqrt(M2) * Mach
    return M

def uvp(w,r, theta, dr, dtheta,  Mah):
    id, jd = w.shape
    id -= 1
    jd -=1
    cv = np.zeros(id + 1)
    cu = 1/ (2 * dr)
    for i in range(id + 1):
        cv[i] = 0.5 / (r[i] * dtheta)
    u = np.zeros((id + 1, jd + 1))
    v = np.zeros((id + 1, jd + 1))
    p = np.ones((id + 1, jd + 1))
    cMM = Mah * Mah * (gamma + 1) / 2
    for j in range(1, jd):
        for i in range(1, id):
            u[i, j] = (w[i + 1, j] - w[i - 1, j]) * cu
            v[i, j] = (w[i, j + 1] - w[i, j - 1]) * cv[i]
            VV = u[i, j]**2 + v[i, j]**2
            q = (1. - VV) * cMM + 1
            p[i, j] = np.sqrt(q) * q**2
        v[0, j] = v[1, j]
        u[0, j] = u[1, j]
        v[id, j] = v[id - 1, j]
        u[id, j] = u[id -1, j]
        p[0][j] = p[1][j]
        p[id][j] = p[id - 1][j]
    for i in range(1, id - 1):
        u[i, 0] = u[i, 1]
        u[i, jd] = u[i, jd - 1]
        v[i, 0] = v[i, 1]
        v[i, jd] = v[i, jd - 1]
        p[i][0] = p[i][1]
        p[i][jd] = p[i][jd - 1]
    return u, v, p

def plot_polar_data(data, r, theta, data_name, Mach_number="", filename=""):
    R, Theta = np.meshgrid(r, theta)
    fig = plt.figure(figsize=(15, 10))
    ax = fig.add_subplot(111)
    c = ax.contourf(R, Theta, data.T, cmap='viridis')
    plt.colorbar(c, label=data_name)
    plt.title(f'График {data_name} в полярных координатах (Mach {Mach_number})')
    ax.set_xlabel('r', fontsize=18)
    ax.set_ylabel(r'$\theta$', fontsize=18)
    if filename:
        if Mach_number:
            plt.savefig(f"{filename}_Mach_{Mach_number}.png")
        else:
            plt.savefig(f"{filename}.png")
    plt.show()

# %%
paths = ["FEM_100_100_0.000000_36490", "FEM_100_100_0.100000_36627", "FEM_100_100_0.200000_37045", 
        "FEM_100_100_0.300000_37763", "FEM_100_100_0.400000_38834"]

paths_chess = ["chess_100_100_0.000000_2528", "chess_100_100_0.100000_2552", "chess_100_100_0.200000_2628", 
              "chess_100_100_0.300000_2773", "chess_100_100_0.400000_3034"]

#"FEM_100_100_0.450000_39562

"chess_100_100_0.450000_3267"
# Out:
# 'chess_100_100_0.450000_3267'

# %%
root_path = "../results/"

def read_data(file_path):
    file_path = root_path + file_path
    file_path_phi = file_path + ".txt"
    file_path_r = file_path + "_r.txt"
    file_path_theta = file_path + "_theta.txt"
    Mach = float(file_path.split("_")[3])
    phi = np.loadtxt(file_path_phi)
    r = np.loadtxt(file_path_r)
    theta = np.loadtxt(file_path_theta)
    dr = r[1] - r[0]
    dtheta = theta[1] - theta[0]
    return phi, r, theta, dr, dtheta, Mach

file_path = "FEM_100_100_0.100000_36627"

# %%
plt.figure(figsize=(15, 10))

for path in paths:
    phi, r, theta, dr, dtheta, Mach = read_data(path)
    u, v, p = uvp(phi, r, theta, dr, dtheta, Mach)
    M = get_local_Mach(u, v, p, Mach)
    plt.plot(theta, get_local_Mach(u, v, p, Mach), label = "Mach {}".format(Mach))    
    
plt.legend(fontsize = 15)
plt.title("Локальное число Маха, явный метод", fontsize = 15)
plt.xlabel(r"$\theta$", fontsize=15)
plt.ylabel(r"M", fontsize=15)
plt.show()

# %%
for path in paths:
    phi, r, theta, dr, dtheta, Mach = read_data(path)
    u, v, p = uvp(phi, r, theta, dr, dtheta, Mach)
    plot_u
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_68680/2361743332.py in <module>
#       2     phi, r, theta, dr, dtheta, Mach = read_data(path)
#       3     u, v, p = uvp(phi, r, theta, dr, dtheta, Mach)
# ----> 4     plot_u
#
# NameError: name 'plot_u' is not defined

# %%
plt.figure(figsize=(15, 10))

for path in paths_chess:
    phi, r, theta, dr, dtheta, Mach = read_data(path)
    u, v, p = uvp(phi, r, theta, dr, dtheta, Mach)
    M = get_local_Mach(u, v, p, Mach)
    plt.plot(theta, get_local_Mach(u, v, p, Mach), label = "Mach {}".format(Mach))    
    
plt.legend(fontsize = 15)
plt.title("Локальное число Маха, шахматный метод", fontsize = 15)
plt.xlabel(r"$\theta$", fontsize=15)
plt.ylabel(r"M", fontsize=15)
plt.show()

# %%
file_path = "FEM_100_100_0.100000_36627"

phi, r, theta, dr, dtheta, Mach = read_data(file_path)

u, v, p = uvp(phi, r, theta, dr, dtheta, Mach)

plot_polar_data(u, r, theta, 'Скорость u', Mach_number=Mach, filename='u_graph')
plot_polar_data(u, r, theta, 'Скорость u', Mach_number=Mach, filename='u_graph')

# %%
Plot(r, theta, phi)

# %%
plot_u(u, r, theta)

# %%
plot_v(v, r, theta)

# %%
plot_p(p, r, theta)

# %%
M0 =

# %%
M1 = get_local_Mach(u, v, p, Mach)

# %%
M2 = get_local_Mach(u, v, p, Mach)

# %%
plt.figure(figsize=(15, 10))

plt.plot(theta, get_local_Mach(u, v, p, Mach), label = "Mach {}".format(Mach))
plt.legend()
plt.show()

# %%
add_Mach_line(ax, theta, u, v, p, Mach)

# %%
plt.xlabel('Theta')
plt.ylabel('Local Mach')
plt.title('Dependence on Mach')
plt.show()
